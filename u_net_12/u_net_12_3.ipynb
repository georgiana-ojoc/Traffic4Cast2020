# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Wed Jun 23 13:08:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory

ram = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM.'.format(ram))
if ram < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type", then select High-RAM in the Runtime shape dropdown '
          'and then re-execute this cell.')
else:
    print('You are using a high-RAM runtime.')
# Out:
# Your runtime has 13.6 gigabytes of available RAM.
# To enable a high-RAM runtime, select the Runtime > "Change runtime type", then select High-RAM in the Runtime shape dropdown and then re-execute this cell.

# %%
from tensorflow import config

physical_devices = config.list_physical_devices('GPU')
try:
    config.experimental.set_memory_growth(physical_devices[0], True)
except Exception as exception:
    print(exception)

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/66/4b/e893d194e626c24b3df2253066aa418f46a432fdb68250cde14bf9bb0700/tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl (679kB)
#      |████████████████████████████████| 686kB 7.5MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.13.0

# %%
from keras.utils.vis_utils import plot_model
from tensorflow import device
from tensorflow import image
from tensorflow_addons import layers as new_layers
from tensorflow.keras import activations
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
from tensorflow.keras import optimizers

import csv
import gc
import h5py
import numpy as np
import os

# %%
town = 'Istanbul'  #@param ['Berlin', 'Istanbul', 'Moscow']

dynamic_files = '/content/gdrive/My Drive/Licenta/Traffic4Cast/{}/files/training'.format(town)
static_file_path = '/content/gdrive/My Drive/Licenta/Traffic4Cast/{}/files/{}_static_2019.h5'.format(town, town.upper())

checkpoints = '/content/gdrive/My Drive/Licenta/Traffic4Cast/{}/checkpoints/UNet12_2'.format(town)
logs = '/content/gdrive/My Drive/Licenta/Traffic4Cast/{}/logs/UNet12_2/training/logs.csv'.format(town)

# %%
def get_file_names(files):
    file_names = os.listdir(files)
    np.random.shuffle(file_names)
    return file_names

# %%
def get_dynamic_data(file_path, index):
    file = h5py.File(file_path, 'r')
    group_key = list(file.keys())[0]
    data = np.array(file[group_key][index:index + 72], dtype=np.float32)  # (72, 495, 436, 9)
    file.close()
    return data

# %%
def get_static_data(file_path):
    file = h5py.File(file_path, 'r')
    group_key = list(file.keys())[0]
    data = np.array(file[group_key][:], dtype=np.float32)  # (495, 436, 7)
    file.close()
    return data

# %%
def get_data(file_path, index, static_data):
    data = get_dynamic_data(file_path, index)
    data = np.array(np.split(data, 3))  # split in 3 batches of 12 + 12 timestamps
    np.random.shuffle(data)  # shuffle the batches
    inputs = data[:, :12, :, :, :]
    outputs = data[:, 12:, :, :, :]
    outputs = np.take(outputs, np.arange(8), axis=-1)  # keep only the dynamic channels
    inputs = np.moveaxis(inputs, 1, -1).reshape((3, 495, 436, -1))  # combine the timestamps with the channels
    outputs = np.moveaxis(outputs, 1, -1).reshape((3, 495, 436, -1))  # combine the timestamps with the channels
    static_data = np.repeat(np.expand_dims(static_data, axis=0), repeats=3, axis=0)  # (3, 495, 436, 7)
    inputs = np.concatenate((inputs, static_data), axis=-1)  # add static data
    return inputs / 255.0, outputs / 255.0

# %%
def get_convolution_block(inputs, filters):
    outputs = layers.Conv2D(filters=filters, kernel_size=3, padding='same')(inputs)
    outputs = layers.BatchNormalization()(outputs)
    outputs = layers.Activation(activations.elu)(outputs)

    outputs = layers.Conv2D(filters=filters, kernel_size=3, padding='same')(outputs)
    outputs = layers.BatchNormalization()(outputs)
    outputs = layers.Activation(activations.elu)(outputs)

    return outputs

# %%
def get_encoder_block(inputs, filters):
    outputs = get_convolution_block(inputs, filters)  # skip features
    pool = layers.MaxPool2D(pool_size=2, strides=2, padding='same')(outputs)
    return outputs, pool

# %%
def get_decoder_block(inputs, skip_features, filters):
    outputs = layers.Conv2DTranspose(filters=filters, kernel_size=2, strides=2, padding='same')(inputs)
    outputs = image.resize(outputs, skip_features.get_shape()[1:3])
    outputs = layers.Concatenate()([outputs, skip_features])
    outputs = get_convolution_block(outputs, filters)
    return outputs

# %%
def get_model():
    inputs = layers.Input(shape=(495, 436, 115), name='inputs')

    encoder_block_1, pool_1 = get_encoder_block(inputs, filters=64)
    encoder_block_2, pool_2 = get_encoder_block(pool_1, filters=128)
    encoder_block_3, pool_3 = get_encoder_block(pool_2, filters=256)
    encoder_block_4, pool_4 = get_encoder_block(pool_3, filters=512)

    convolution_block = get_convolution_block(pool_4, 1024)

    decoder_block_1 = get_decoder_block(convolution_block, encoder_block_4, 512)
    decoder_block_2 = get_decoder_block(decoder_block_1, encoder_block_3, 256)
    decoder_block_3 = get_decoder_block(decoder_block_2, encoder_block_2, 128)
    decoder_block_4 = get_decoder_block(decoder_block_3, encoder_block_1, 64)

    outputs = layers.Conv2D(filters=96, kernel_size=1, padding='same')(decoder_block_4)

    return models.Model(inputs=inputs, outputs=outputs)

# %%
with device('gpu:0'):
    model = get_model()
    model.compile(optimizer=optimizers.Adam(learning_rate=0.0003), loss=losses.mean_squared_error)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 495, 436, 11 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 495, 436, 64) 66304       inputs[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 495, 436, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 495, 436, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 495, 436, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 495, 436, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 495, 436, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 248, 218, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 248, 218, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 248, 218, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 248, 218, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 248, 218, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 248, 218, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 248, 218, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 124, 109, 128 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 124, 109, 256 295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 124, 109, 256 1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 124, 109, 256 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 124, 109, 256 590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 124, 109, 256 1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 124, 109, 256 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 62, 55, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 62, 55, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 62, 55, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 62, 55, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 62, 55, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 62, 55, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 62, 55, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 31, 28, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 31, 28, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 31, 28, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 31, 28, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 31, 28, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 31, 28, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 31, 28, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 62, 56, 512)  2097664     activation_9[0][0]
# __________________________________________________________________________________________________
# tf.image.resize (TFOpLambda)    (None, 62, 55, 512)  0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 62, 55, 1024) 0           tf.image.resize[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 62, 55, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 62, 55, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 62, 55, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 62, 55, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 62, 55, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 62, 55, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 124, 110, 256 524544      activation_11[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_1 (TFOpLambda)  (None, 124, 109, 256 0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 124, 109, 512 0           tf.image.resize_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 124, 109, 256 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 124, 109, 256 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 124, 109, 256 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 124, 109, 256 590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 124, 109, 256 1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 124, 109, 256 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 248, 218, 128 131200      activation_13[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_2 (TFOpLambda)  (None, 248, 218, 128 0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 248, 218, 256 0           tf.image.resize_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 248, 218, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 248, 218, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 248, 218, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 248, 218, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 248, 218, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 248, 218, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 496, 436, 64) 32832       activation_15[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_3 (TFOpLambda)  (None, 495, 436, 64) 0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 495, 436, 128 0           tf.image.resize_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 495, 436, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 495, 436, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 495, 436, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 495, 436, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 495, 436, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 495, 436, 64) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 495, 436, 96) 6240        activation_17[0][0]
# ==================================================================================================
# Total params: 31,125,984
# Trainable params: 31,114,208
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='u_net_12_3.png', show_shapes=True, show_layer_names=True)

# %%
static_data = get_static_data(static_file_path)

log_file = open(logs, 'w', newline='')
log_writer = csv.writer(log_file)
log_writer.writerow(['epoch', 'file', 'loss'])
log_file.flush()

# %%
for epoch in range(5):
    print('epoch:', epoch)
    file_names = get_file_names(dynamic_files)
    for index, file_name in enumerate(file_names):
        print('file:', index)
        losses = np.zeros(shape=(4,), dtype=np.float64)
        for index in range(0, 288, 72):
            inputs, outputs = get_data(os.path.join(dynamic_files, file_name), index, static_data)
            with device('gpu:0'):
                history = model.fit(inputs, outputs, epochs=1, batch_size=3)
                losses[index // 72] = history.history['loss'][0]
        log_writer.writerow([epoch, file_name, np.mean(losses, dtype=np.float64)])
        log_file.flush()
        gc.collect()
    model.save(os.path.join(checkpoints, 'model_{}.h5'.format(epoch)))

# %%
log_file.close()
